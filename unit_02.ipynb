# %% [markdown]
# ## LIST VS numPy ARRAY

# %%
import numpy as np

# %%
py_list = [ 1,3,6]
print("Py list multiplication:",py_list * 2)

np_array = np.array([2,5,6,7])  # Scalar multiplication
print("np array multiplication:",np_array * 2)
# Out:
# Py list multiplication: [1, 3, 6, 1, 3, 6]
# np array multiplication: [ 4 10 12 14]

# %% [markdown]
# 🔹 Who is Fast numPy or list:

# %%
import time 
start = time.time()
list_py = [i*2 for i in range(10000)]
print("List operation time:",time.time() - start)

array = np.arange(1000) * 2
print("NumPy operation time:",time.time() - start)
# Out:
# List operation time: 0.0005745887756347656
# NumPy operation time: 0.0009562969207763672

# %% [markdown]
# ### 🔹File handling in Numpy :

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
arr1 = np.array([[2,5,4],[5,8,1]])
arr2 = np.random.rand(3,3)
arr3 = np.zeros((3,3))

# %%
# Save method to Save arrays : 😁
# np.save('array_name.npy',array_name)

np.save('arr1.npy',arr1)
np.save('arr2.npy',arr2)
np.save('arr3.npy',arr3)

# %%
# Save and Display the arrays :
# a = np.load('array_name.npy')
# print(a)

load_arr = np.load('arr1.npy')
print(load_arr)
# Out:
# [[2 5 4]
#  [5 8 1]]
